# %% [markdown]
# ![Screen%20Shot%202018-07-31%20at%209.23.04%20PM.png](attachment:Screen%20Shot%202018-07-31%20at%209.23.04%20PM.png)

# %%
n = 6 
k = 3
ar = [1, 3, 2, 6, 1, 2]

def divisibleSumPairs(n, k, ar):
    count = 0
    for i in range(len(ar)-1):
        for j in range(i+1, len(ar)):
            if (ar[i]+ar[j])%k == 0:
                count +=1
    return count
    
divisibleSumPairs(n, k, ar)
# Out:
# 5
